# %%
from IPython.display import clear_output
# !pip install requests
# !pip install --upgrade pandas
# !pip install konlpy
# !pip install gensim
# !cp -R /home/work/deep/jdk1.8.0_201 /usr/lib/jvm
clear_output()

# %%
# !pip install plotly
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('kyoh', 'xLxYyOTECJ48ofwzrn2j')
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
clear_output()

# %%
import pandas as pd
import numpy as np
import requests
features = []

# %% [markdown]
# ### 1) 국제 원유가격 데이터에서 예측할 두바이유 데이터 로드 및 추세 확인
# ### 2) 피쳐로 사용할 데이터 탐색
# ### - 국제 유가 관련 뉴스 데이터(제외)
# ### - 다우 존스 데이터
# ### - 환율 데이터
# ### - 코스피 데이터
# ### - Brent 데이터
# ### - WTI 데이터
# ### - 국제 유가에 주가 상승 영향을 받는 국내 주식 종목
# ###   (SK이노베이션,S-OIL,한화케미칼)
# ### - 국제 유가에 주가 하락 영향을 받는 국내 주식 종목
# ###   (아시아나항공,대한항공,현대상선)
# ### 3) 모델링

# %% [markdown]
# #### 1) 국제 원유가격 데이터에서 예측할 두바이유 데이터 로드 및 추세 확인
# #### 국제 원유가격(Brent, WTI, 두바이) 데이터 로드 및 전처리
# #### df_oil_price

# %%
df_oil_price = pd.read_csv('국제_원유가격20080607_20190610.csv', encoding='UTF-8')
df_oil_price.columns = ['time','dubai','brent','WIT']

df_oil_price['time'] = '20'+df_oil_price.time
df_oil_price['time'] = pd.to_datetime(df_oil_price['time'], format='%Y년%m월%d일')
#df_oil_price = df_oil_price.drop(df.index[list(df_WTI[df_WTI.price=='.'].index)])
#df_WTI['price']= df_WTI.price.astype('float')
#df=df.merge(df_oil,how='outer',on="time")

# %% [markdown]
# #### 데이터 중 이상치가 있으면 전일 값, 전전일 값으로 대체

# %%
df_oil_price.dubai = np.where(df_oil_price.dubai == '-', df_oil_price.dubai.shift(-1) , df_oil_price.dubai)
df_oil_price.dubai = np.where(df_oil_price.dubai == '-', df_oil_price.dubai.shift(-2) , df_oil_price.dubai)
df_oil_price.brent = np.where(df_oil_price.brent == '-', df_oil_price.brent.shift(-1) , df_oil_price.brent)
df_oil_price.brent = np.where(df_oil_price.brent == '-', df_oil_price.brent.shift(-2) , df_oil_price.brent)
df_oil_price.WIT = np.where(df_oil_price.WIT == '-', df_oil_price.WIT.shift(-1) , df_oil_price.WIT)
df_oil_price.WIT = np.where(df_oil_price.WIT == '-', df_oil_price.WIT.shift(-2) , df_oil_price.WIT)

# %%
df_oil_price.dubai = df_oil_price.dubai.astype(float)
df_oil_price.brent = df_oil_price.brent.astype(float)
df_oil_price.WIT = df_oil_price.WIT.astype(float)

# %%
features.append(df_oil_price)

# %%
#기술 통계
df_oil_price.describe()
# Out:
#              dubai        brent          WIT
# count  2840.000000  2840.000000  2840.000000
# mean     77.314197    80.033173    73.468486
# std      25.929948    26.372873    23.115252
# min      22.830000    27.880000    26.210000
# 25%      54.167500    56.007500    51.697500
# 50%      73.750000    75.585000    72.480000
# 75%     104.472500   107.737500    93.825000
# max     140.700000   146.080000   145.290000

# %%
trace_brent = go.Scatter(
                x=df_oil_price.time,
                y=df_oil_price['brent'],
                name = "brent",
                line = dict(color = '#89d5c9'),
                opacity = 0.8)

trace_dubai = go.Scatter(
                x=df_oil_price.time,
                y=df_oil_price['dubai'],
                name = "dubai",
                line = dict(color = '#e25b45'),
                opacity = 0.8)

trace_WIT = go.Scatter(
                x=df_oil_price.time,
                y=df_oil_price['WIT'],
                name = "WIT",
                line = dict(color = '#adc965'),
                opacity = 0.8)
data = [trace_brent,trace_dubai,trace_WIT]
layout = dict(
    title = "국제 유가 추이",)
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "국제 유가 추이")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kyoh/25.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## News Data Load(국제유가 관련 뉴스)
# ## 감정분석 전처리한 데이터 Load

# %%
df = pd.read_csv('news_pn.csv', encoding='UTF-8',index_col=0)
df['time'] = pd.to_datetime(df.time, format='%Y-%m-%d')

# %%
df.head()
# Out:
#         time      positive  negative
# 0 2019-06-08  7.549430e-24  1.000000
# 1 2019-05-15  1.199353e-14  1.000000
# 2 2019-05-14  2.339850e-02  0.976601
# 3 2019-05-08  0.000000e+00  1.000000
# 4 2019-05-07  0.000000e+00  1.000000

# %% [markdown]
# ## Load 주유소 기름 Data

# %%
df_oil = pd.read_csv('주유소_평균판매가격_제품별.csv',encoding='UTF-8')
df_oil['time'] = pd.to_datetime(df_oil['구분'], format='%Y년%m월%d일')
df_oil.drop('구분',axis=1,inplace=True)
#df = df_oil[['time','고급휘발유','보통휘발유','자동차용경유']].merge(df,on='time',how='outer').fillna(0)
#oil_dubai_df =pd.merge(df_oil, df_oil_price[['time','dubai']], how='right',on='time').dropna(how='any').set_index('time')

# %%
features.append(df_oil)

# %%
trace_1 = go.Scatter(
                x=df_all.index,
                y=x[:,3],
                name = "고급휘발유",
                line = dict(color = '#89d5c9'),
                opacity = 0.8)

trace_2 = go.Scatter(
                x=df_all.index,
                y=x[:,4],
                name = "보통휘발유",
                line = dict(color = '#e25b45'),
                opacity = 0.8)

trace_3 = go.Scatter(
                x=df_all.index,
                y=x[:,5],
                name = "자동차용경유",
                line = dict(color = '#adc965'),
                opacity = 0.8)
trace_4 = go.Scatter(
                x=df_all.index,
                y=x[:,0],
                name = "두바이유",
                line = dict(color = 'red'),
                opacity = 1)
data = [trace_1,trace_2,trace_3,trace_4]
layout = dict(
    title = "국제유가와 국내 기름값 추이",)
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "국제유가와 국내 기름값 추이")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kyoh/35.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## 다우존스 / 코스피 Data

# %%
df_dji = pd.read_csv('다우존스 내역.csv', encoding='UTF-8')
kospi = pd.read_csv('코스피지수 내역.csv', encoding='UTF-8')
df_dji['날짜'] = pd.to_datetime(df_dji['날짜'], format='%Y년 %m월 %d일')
kospi['날짜'] = pd.to_datetime(kospi['날짜'], format='%Y년 %m월 %d일')
df_dji['현재가'] = df_dji['현재가'].str.replace(',','').astype('float')
kospi['현재가'] = kospi['현재가'].str.replace(',','').astype('float')
df_stock = df_dji[['날짜','현재가']].merge(kospi[['날짜','현재가']],on='날짜',how='outer')
df_stock.columns = ['time','다우존스','코스피']
#df_stock['현재가_x'] = df_stock['현재가_x'].fillna(df_stock.현재가_x.astype('float32').mean())
#df_stock['현재가_y'] = df_stock['현재가_y'].fillna(df_stock.현재가_y.astype('float32').mean())
#df_stock['time'] = df_stock['날짜'].dt.strftime('%Y-%m-%d')
#df_stock['time'] = pd.to_datetime(df_stock['날짜'], format='%Y-%m-%d')
#df_stock.drop('날짜',axis=1,inplace=True)
#df_stock.columns = ['다우존스','코스피','time']
#stock_df=pd.merge(df_stock, df_oil_price[['time','dubai']], how='right',on='time').dropna(how='any').set_index('time')

# %%
features.append(df_stock)

# %%
trace_1 = go.Scatter(
                x=df_all.index,
                y=x[:,6],
                name = "다우존스",
                line = dict(color = '#89d5c9'),
                opacity = 0.8)
trace_2 = go.Scatter(
                x=df_all.index,
                y=x[:,7],
                name = "코스피",
                line = dict(color = '#e25b45'),
                opacity = 0.8)
trace_3 = go.Scatter(
                x=df_all.index,
                y=x[:,0],
                name = "두바이유",
                line = dict(color = 'red'),
                opacity = 1)
data = [trace_1,trace_2,trace_3]
layout = dict(
    title = "국제유가와 코스피/다우존스 기름값 추이",)
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "국제유가와 국내 기름값 추이")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kyoh/35.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## 환율 Data(USD)
# ## df_er

# %% [markdown]
# usd_list = []
# for date in list(df.time.unique()):
#     url = 'https://www.koreaexim.go.kr/site/program/financial/exchangeJSON?authkey=E24WPCtlRO2NyplVreVjosPe4XmFFtmb&searchdate={}&data=AP01'.format(date)
#     print('{} search start'.format(date))
#     try:
#         response = requests.get(url)
#     except:
#         print('retry')
#         response = requests.get(url)
#     if len(response.json()) == 0:
#         usd_list.append(None)
#         print('Null')
#     else:
#         for i in response.json():m
#             if i['cur_unit'] == 'USD':
#                 usd_list.append(i['ttb'])
#                 print(i['ttb'])
#     print('{} search end'.format(date))

# %% [markdown]
# pd.DataFrame(data={'er':usd_list,'time':df.time.unique()}).to_csv('er.csv',encoding='UTF-8')

# %%
df_er = pd.read_csv('er.csv',encoding='UTF-8')
df_er['er'] = df_er['er'].str.replace(',','').astype('float')
#df_er['er'] = df_er['er'].fillna(df_er['er'].mean())
df_er['time'] = pd.to_datetime(df_er['time'], format='%Y-%m-%d')
df_er = df_er[(df_er.time <= '2019-06-10')&(df_er.time >= '2008-06-09')]

# %%
for i in range(5):
    df_er.er = np.where(df_er.er.isnull(), df_er.er.shift(-i) , df_er.er)
df_er.er.isnull().sum().sum()
# Out:
# 0

# %%
features.append(df_er)

# %%
trace_1 = go.Scatter(
                x=df_all.index,
                y=x[:,8],
                name = "환율",
                line = dict(color = '#89d5c9'),
                opacity = 0.8)
trace_2 = go.Scatter(
                x=df_all.index,
                y=x[:,0],
                name = "두바이유",
                line = dict(color = 'red'),
                opacity = 1)
data = [trace_1,trace_2]
layout = dict(
    title = "국제유가와 환율가격 추이",)
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "국제유가와 환율가격 추이")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kyoh/37.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### 국제 유가에 주가 상승과 하락에 영향을 받는 국내 주식 종목 데이터 로드
# ### (SK이노베이션,S-OIL,한화케미칼,아시아나항공,대한항공,현대상선)
# ### 로드 방법

# %% [markdown]
# !pip install bs4
# import urllib
# import time
#
# from urllib.request import urlopen
# from bs4 import BeautifulSoup
#
# total_lists =[]
#
# stockItems = ['096770','010950','009830','020560','003490','004870']
#
# for stockItem in stockItems:
#     timestamp = []
#     data = []
#     print('{} start'.format(stockItem))
#     url = 'http://finance.naver.com/item/sise_day.nhn?code='+ stockItem
#     html = urlopen(url)
#     source = BeautifulSoup(html.read(), "html.parser")
#     maxPage=source.find_all("table",align="center")
#     mp = maxPage[0].find_all("td",class_="pgRR")
#     #mpNum = int(mp[0].a.get('href')[-3:])
#     mpNum = 283
#     print(mpNum)
#
#     for page in range(1, mpNum+1):
#         url = 'http://finance.naver.com/item/sise_day.nhn?code=' + stockItem +'&page='+ str(page)
#         html = urlopen(url)
#         source = BeautifulSoup(html.read(), "html.parser")
#         srlists=source.find_all("tr")
#         isCheckNone = None
#         if((page % 1) == 0):
#             time.sleep(1.50)
#         for i in range(1,len(srlists)-1):
#             if(srlists[i].span != isCheckNone):
#                 srlists[i].td.text
#                 timestamp.append(srlists[i].find_all("td",align="center")[0].text)
#                 data.append(srlists[i].find_all("td",class_="num")[0].text )
#     df = pd.DataFrame(data={'time':timestamp,'{}'.format(stockItem):data})
#     total_lists.append(df)

# %% [markdown]
# df_stock = pd.DataFrame({'time': total_lists[0].time})
# for f in total_lists :
#     df_stock = pd.merge(df_stock, f, how='left',on='time')
# display(df_stock.shape)

# %% [markdown]
# df_stock.to_csv('stock_price.csv',encoding='UTF-8')

# %%
df_stock_price = pd.read_csv('stock_price.csv',encoding='UTF-8',index_col=0)
df_stock_price.fillna('6,580',inplace=True)
df_stock_price['time'] = pd.to_datetime(df_stock_price['time'], format='%Y.%m.%d')
df_stock_price = df_stock_price[(df_stock_price.time <= '2019-06-10')&(df_stock_price.time >= '2008-06-09')]
df_stock_price.describe()
df_stock_price.shape
# Out:
# (2723, 7)

# %%
features.append(df_stock_price)

# %%
trace_1 = go.Scatter(
                x=df_all.index,
                y=x[:,9],
                name = "SK이노베이션",
                line = dict(color = '#89d5c9'),
                opacity = 0.8)

trace_2 = go.Scatter(
                x=df_all.index,
                y=x[:,10],
                name = "S-OIL",
                line = dict(color = '#e25b45'),
                opacity = 0.8)

trace_3 = go.Scatter(
                x=df_all.index,
                y=x[:,11],
                name = "한화케미칼",
                line = dict(color = '#adc965'),
                opacity = 0.8)
trace_4 = go.Scatter(
                x=df_all.index,
                y=x[:,0],
                name = "두바이유",
                line = dict(color = 'red'),
                opacity = 1)
data = [trace_1,trace_2,trace_3,trace_4]
layout = dict(
    title = "국제 유가에 주가 상승 영향을 받는 국내 주식 종목",)
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "국제 유가에 주가 상승 영향을 받는 국내 주식 종목")
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kyoh/31.embed" height="525px" width="100%"></iframe>

# %%
trace_1 = go.Scatter(
                x=df_all.index,
                y=x[:,12],
                name = "아시아나항공",
                line = dict(color = '#89d5c9'),
                opacity = 0.8)

trace_2 = go.Scatter(
                x=df_all.index,
                y=x[:,13],
                name = "대한항공",
                line = dict(color = '#e25b45'),
                opacity = 0.8)

trace_3 = go.Scatter(
                x=df_all.index,
                y=x[:,14],
                name = "현대상선",
                line = dict(color = '#adc965'),
                opacity = 0.8)
trace_4 = go.Scatter(
                x=df_all.index,
                y=x[:,0],
                name = "두바이유",
                line = dict(color = 'red'),
                opacity = 1)
data = [trace_1,trace_2,trace_3,trace_4]
layout = dict(
    title = "국제 유가에 주가 하락 영향을 받는 국내 주식 종목",)
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "국제 유가에 주가 하락 영향을 받는 국내 주식 종목")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kyoh/33.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### -  데이터 머징

# %%
len(features)
# Out:
# 5

# %%
df_all = pd.DataFrame({'time': df_oil_price.time.unique()})

# %%
for f in features :
    df_all = pd.merge(df_all, f, how='left',on='time').dropna(how='any').set_index('time')

# %%
df_all = pd.merge(df_all, df, how='left',on='time').fillna(0).set_index('time')

# %%
df_all.columns
# Out:
# Index(['dubai', 'brent', 'WIT', '고급휘발유', '보통휘발유', '자동차용경유', '다우존스', '코스피',
#        'er', '096770', '010950', '009830', '020560', '003490', '004870',
#        'positive', 'negative'],
#       dtype='object')

# %%
df_all.shape
# Out:
# (2537, 17)

# %% [markdown]
# #### 모델링

# %%
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense
from keras import backend as K
from keras import layers
from keras import backend as K
from keras import optimizers
from keras.utils import plot_model
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from keras.preprocessing import image

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import MinMaxScaler
scalerX = MinMaxScaler()
x = scalerX.fit_transform(df_all)
scalery = MinMaxScaler()
y = scalery.fit_transform(df_all.iloc[:,[0]])

# %%
plt.plot(y)
plt.xlabel("Time Period")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
# Your answer comes here.
SEQ_LEN = 5

# build a dataset
dataX = []
dataY = []

for i in range(0, len(y) - SEQ_LEN):
    _x = x[i:i + SEQ_LEN]
    _y = y[i + SEQ_LEN]
    dataX.append(_x)
    dataY.append(_y)

dataX = np.array(dataX)
dataY = np.array(dataY)

# %%
dataY.shape
# Out:
# (2532, 1)

# %%
train_size = int(len(dataY) * 0.8)
test_size = len(dataY) - train_size
Xtrain, Xtest = np.array(dataX[0:train_size]), np.array(dataX[train_size:len(dataX)])
ytrain, ytest = np.array(dataY[0:train_size]), np.array(dataY[train_size:len(dataY)])

# %%
np.shape(Xtrain), np.shape(Xtest)
# Out:
# ((2025, 5, 17), (507, 5, 17))

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(128, input_shape=(5, 17),return_sequences=True))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mae'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 5, 128)            74752
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 124,225
# Trainable params: 124,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(64, input_shape=(5, 17),return_sequences=True))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mae'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 5, 64)             20992
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 33,441
# Trainable params: 33,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(128, input_shape=(5, 15),return_sequences=True))
model.add(layers.Dropout(0.2))
model.add(LSTM(64, return_sequences=True))
model.add(layers.Dropout(0.2))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mae'])
model.summary()

# %%
# Your answer comes here.
from keras.callbacks import TensorBoard
import time
now = time.strftime("%c")
callbacks_list = [
    ModelCheckpoint(filepath='stock'+now+'.h5',monitor='val_loss',save_best_only=True),
    TensorBoard(log_dir='/home/work/logs/oil_price/'+'stock'+now+'.h5')
]
history=model.fit(Xtrain, ytrain,batch_size = 128,epochs=500,validation_split = 0.2, verbose=1,callbacks=callbacks_list)
# Out:
# Train on 1620 samples, validate on 405 samples
# Epoch 1/500
# 1620/1620 [==============================] - 1s 749us/step - loss: 0.0809 - mean_absolute_error: 0.2244 - val_loss: 0.0448 - val_mean_absolute_error: 0.2078
# Epoch 2/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 0.0122 - mean_absolute_error: 0.0910 - val_loss: 0.0487 - val_mean_absolute_error: 0.2177
# Epoch 3/500
# 1620/1620 [==============================] - 0s 182us/step - loss: 0.0054 - mean_absolute_error: 0.0562 - val_loss: 0.0187 - val_mean_absolute_error: 0.1315
# Epoch 4/500
# 1620/1620 [==============================] - 0s 188us/step - loss: 0.0028 - mean_absolute_error: 0.0389 - val_loss: 0.0197 - val_mean_absolute_error: 0.1364
# Epoch 5/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 0.0016 - mean_absolute_error: 0.0285 - val_loss: 0.0088 - val_mean_absolute_error: 0.0876
# Epoch 6/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 0.0012 - mean_absolute_error: 0.0245 - val_loss: 0.0045 - val_mean_absolute_error: 0.0594
# Epoch 7/500
# 1620/1620 [==============================] - 0s 194us/step - loss: 0.0010 - mean_absolute_error: 0.0235 - val_loss: 0.0030 - val_mean_absolute_error: 0.0463
# Epoch 8/500
# 1620/1620 [==============================] - 0s 189us/step - loss: 9.0384e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0022 - val_mean_absolute_error: 0.0387
# Epoch 9/500
# 1620/1620 [==============================] - 0s 190us/step - loss: 8.4382e-04 - mean_absolute_error: 0.0220 - val_loss: 0.0017 - val_mean_absolute_error: 0.0340
# Epoch 10/500
# 1620/1620 [==============================] - 0s 195us/step - loss: 7.9823e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0015 - val_mean_absolute_error: 0.0316
# Epoch 11/500
# 1620/1620 [==============================] - 0s 198us/step - loss: 7.5835e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0014 - val_mean_absolute_error: 0.0310
# Epoch 12/500
# 1620/1620 [==============================] - 0s 203us/step - loss: 7.2592e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0013 - val_mean_absolute_error: 0.0300
# Epoch 13/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 6.9984e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0014 - val_mean_absolute_error: 0.0315
# Epoch 14/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 6.7026e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0014 - val_mean_absolute_error: 0.0312
# Epoch 15/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 6.5232e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0013 - val_mean_absolute_error: 0.0301
# Epoch 16/500
# 1620/1620 [==============================] - 0s 201us/step - loss: 6.2437e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 17/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 6.0131e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0013 - val_mean_absolute_error: 0.0298
# Epoch 18/500
# 1620/1620 [==============================] - 0s 186us/step - loss: 5.8733e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 19/500
# 1620/1620 [==============================] - 0s 181us/step - loss: 5.8146e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 20/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 5.8672e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 21/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 5.5245e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0012 - val_mean_absolute_error: 0.0294
# Epoch 22/500
# 1620/1620 [==============================] - 0s 181us/step - loss: 5.3967e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0014 - val_mean_absolute_error: 0.0313
# Epoch 23/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 5.3035e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 24/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 5.2372e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0014 - val_mean_absolute_error: 0.0316
# Epoch 25/500
# 1620/1620 [==============================] - 0s 161us/step - loss: 5.2185e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0012 - val_mean_absolute_error: 0.0288
# Epoch 26/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 5.1472e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0013 - val_mean_absolute_error: 0.0309
# Epoch 27/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 4.9131e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0013 - val_mean_absolute_error: 0.0301
# Epoch 28/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 4.8744e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 29/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 4.8409e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 30/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 4.7980e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0012 - val_mean_absolute_error: 0.0288
# Epoch 31/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 4.6328e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0010 - val_mean_absolute_error: 0.0266
# Epoch 32/500
# 1620/1620 [==============================] - 0s 189us/step - loss: 4.7021e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# Epoch 33/500
# 1620/1620 [==============================] - 0s 162us/step - loss: 4.5122e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0012 - val_mean_absolute_error: 0.0295
# Epoch 34/500
# 1620/1620 [==============================] - 0s 186us/step - loss: 4.6728e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0012 - val_mean_absolute_error: 0.0294
# Epoch 35/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 4.4442e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0010 - val_mean_absolute_error: 0.0264
# Epoch 36/500
# 1620/1620 [==============================] - 0s 201us/step - loss: 4.4819e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0013 - val_mean_absolute_error: 0.0305
# Epoch 37/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 4.6367e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 38/500
# 1620/1620 [==============================] - 0s 164us/step - loss: 4.4786e-04 - mean_absolute_error: 0.0161 - val_loss: 9.6453e-04 - val_mean_absolute_error: 0.0259
# Epoch 39/500
# 1620/1620 [==============================] - 0s 190us/step - loss: 4.2271e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0010 - val_mean_absolute_error: 0.0270
# Epoch 40/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 4.1610e-04 - mean_absolute_error: 0.0155 - val_loss: 9.7414e-04 - val_mean_absolute_error: 0.0261
# Epoch 41/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 4.1385e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0011 - val_mean_absolute_error: 0.0282
# Epoch 42/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 4.1430e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 43/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 4.0971e-04 - mean_absolute_error: 0.0153 - val_loss: 7.8064e-04 - val_mean_absolute_error: 0.0231
# Epoch 44/500
# 1620/1620 [==============================] - 0s 189us/step - loss: 4.1987e-04 - mean_absolute_error: 0.0155 - val_loss: 9.5929e-04 - val_mean_absolute_error: 0.0260
# Epoch 45/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 4.0265e-04 - mean_absolute_error: 0.0152 - val_loss: 9.4614e-04 - val_mean_absolute_error: 0.0259
# Epoch 46/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 3.9355e-04 - mean_absolute_error: 0.0150 - val_loss: 9.6682e-04 - val_mean_absolute_error: 0.0262
# Epoch 47/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 3.8991e-04 - mean_absolute_error: 0.0149 - val_loss: 9.2562e-04 - val_mean_absolute_error: 0.0256
# Epoch 48/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 3.8796e-04 - mean_absolute_error: 0.0149 - val_loss: 7.6572e-04 - val_mean_absolute_error: 0.0230
# Epoch 49/500
# 1620/1620 [==============================] - 0s 192us/step - loss: 3.9927e-04 - mean_absolute_error: 0.0152 - val_loss: 8.7114e-04 - val_mean_absolute_error: 0.0248
# Epoch 50/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 3.9683e-04 - mean_absolute_error: 0.0150 - val_loss: 8.9138e-04 - val_mean_absolute_error: 0.0251
# Epoch 51/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 3.9561e-04 - mean_absolute_error: 0.0150 - val_loss: 9.2951e-04 - val_mean_absolute_error: 0.0257
# Epoch 52/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 3.8355e-04 - mean_absolute_error: 0.0148 - val_loss: 9.5748e-04 - val_mean_absolute_error: 0.0262
# Epoch 53/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 3.7533e-04 - mean_absolute_error: 0.0147 - val_loss: 8.6922e-04 - val_mean_absolute_error: 0.0248
# Epoch 54/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 3.7593e-04 - mean_absolute_error: 0.0147 - val_loss: 7.3801e-04 - val_mean_absolute_error: 0.0226
# Epoch 55/500
# 1620/1620 [==============================] - 0s 194us/step - loss: 3.7461e-04 - mean_absolute_error: 0.0147 - val_loss: 8.5695e-04 - val_mean_absolute_error: 0.0246
# Epoch 56/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 3.6384e-04 - mean_absolute_error: 0.0144 - val_loss: 6.9429e-04 - val_mean_absolute_error: 0.0219
# Epoch 57/500
# 1620/1620 [==============================] - 0s 189us/step - loss: 3.6610e-04 - mean_absolute_error: 0.0144 - val_loss: 7.2024e-04 - val_mean_absolute_error: 0.0224
# Epoch 58/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 3.6698e-04 - mean_absolute_error: 0.0145 - val_loss: 9.4259e-04 - val_mean_absolute_error: 0.0260
# Epoch 59/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 3.6324e-04 - mean_absolute_error: 0.0144 - val_loss: 9.0463e-04 - val_mean_absolute_error: 0.0255
# Epoch 60/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 3.8494e-04 - mean_absolute_error: 0.0149 - val_loss: 7.2752e-04 - val_mean_absolute_error: 0.0225
# Epoch 61/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 3.7443e-04 - mean_absolute_error: 0.0147 - val_loss: 7.2034e-04 - val_mean_absolute_error: 0.0224
# Epoch 62/500
# 1620/1620 [==============================] - 0s 191us/step - loss: 3.5790e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1390e-04 - val_mean_absolute_error: 0.0223
# Epoch 63/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 3.6510e-04 - mean_absolute_error: 0.0145 - val_loss: 8.9260e-04 - val_mean_absolute_error: 0.0253
# Epoch 64/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 3.4844e-04 - mean_absolute_error: 0.0140 - val_loss: 7.5778e-04 - val_mean_absolute_error: 0.0231
# Epoch 65/500
# 1620/1620 [==============================] - 0s 184us/step - loss: 3.5333e-04 - mean_absolute_error: 0.0142 - val_loss: 9.7338e-04 - val_mean_absolute_error: 0.0265
# Epoch 66/500
# 1620/1620 [==============================] - 0s 164us/step - loss: 3.5415e-04 - mean_absolute_error: 0.0142 - val_loss: 6.8732e-04 - val_mean_absolute_error: 0.0220
# Epoch 67/500
# 1620/1620 [==============================] - 0s 183us/step - loss: 3.7557e-04 - mean_absolute_error: 0.0148 - val_loss: 7.8492e-04 - val_mean_absolute_error: 0.0235
# Epoch 68/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 4.0219e-04 - mean_absolute_error: 0.0153 - val_loss: 9.6640e-04 - val_mean_absolute_error: 0.0264
# Epoch 69/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 3.6182e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0011 - val_mean_absolute_error: 0.0284
# Epoch 70/500
# 1620/1620 [==============================] - 0s 161us/step - loss: 3.7469e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 71/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 3.3626e-04 - mean_absolute_error: 0.0138 - val_loss: 7.6909e-04 - val_mean_absolute_error: 0.0234
# Epoch 72/500
# 1620/1620 [==============================] - 0s 186us/step - loss: 3.3933e-04 - mean_absolute_error: 0.0139 - val_loss: 9.2009e-04 - val_mean_absolute_error: 0.0256
# Epoch 73/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 3.5638e-04 - mean_absolute_error: 0.0143 - val_loss: 9.7558e-04 - val_mean_absolute_error: 0.0265
# Epoch 74/500
# 1620/1620 [==============================] - 0s 181us/step - loss: 3.5648e-04 - mean_absolute_error: 0.0142 - val_loss: 9.0804e-04 - val_mean_absolute_error: 0.0255
# Epoch 75/500
# 1620/1620 [==============================] - 0s 166us/step - loss: 3.4331e-04 - mean_absolute_error: 0.0140 - val_loss: 9.0398e-04 - val_mean_absolute_error: 0.0253
# Epoch 76/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 3.7059e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0010 - val_mean_absolute_error: 0.0270
# Epoch 77/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 3.3750e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0011 - val_mean_absolute_error: 0.0290
# Epoch 78/500
# 1620/1620 [==============================] - 0s 183us/step - loss: 3.6304e-04 - mean_absolute_error: 0.0145 - val_loss: 8.5241e-04 - val_mean_absolute_error: 0.0246
# Epoch 79/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 3.4063e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0011 - val_mean_absolute_error: 0.0288
# Epoch 80/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 3.3267e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0010 - val_mean_absolute_error: 0.0273
# Epoch 81/500
# 1620/1620 [==============================] - 0s 162us/step - loss: 3.4282e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0012 - val_mean_absolute_error: 0.0299
# Epoch 82/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 3.3498e-04 - mean_absolute_error: 0.0137 - val_loss: 9.2781e-04 - val_mean_absolute_error: 0.0257
# Epoch 83/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 3.2516e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0010 - val_mean_absolute_error: 0.0275
# Epoch 84/500
# 1620/1620 [==============================] - 0s 164us/step - loss: 3.6547e-04 - mean_absolute_error: 0.0147 - val_loss: 9.8617e-04 - val_mean_absolute_error: 0.0266
# Epoch 85/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 3.5914e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0012 - val_mean_absolute_error: 0.0298
# Epoch 86/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 3.5484e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 87/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 3.2730e-04 - mean_absolute_error: 0.0136 - val_loss: 8.4252e-04 - val_mean_absolute_error: 0.0245
# Epoch 88/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 3.2550e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 89/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 3.2027e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0010 - val_mean_absolute_error: 0.0276
# Epoch 90/500
# 1620/1620 [==============================] - 0s 182us/step - loss: 3.2934e-04 - mean_absolute_error: 0.0138 - val_loss: 9.1555e-04 - val_mean_absolute_error: 0.0256
# Epoch 91/500
# 1620/1620 [==============================] - 0s 182us/step - loss: 3.2125e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0012 - val_mean_absolute_error: 0.0292
# Epoch 92/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 3.1269e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0011 - val_mean_absolute_error: 0.0284
# Epoch 93/500
# 1620/1620 [==============================] - 0s 188us/step - loss: 3.2686e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0013 - val_mean_absolute_error: 0.0316
# Epoch 94/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 3.3089e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 95/500
# 1620/1620 [==============================] - 0s 182us/step - loss: 3.2900e-04 - mean_absolute_error: 0.0137 - val_loss: 8.9371e-04 - val_mean_absolute_error: 0.0253
# Epoch 96/500
# 1620/1620 [==============================] - 0s 165us/step - loss: 3.3350e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0015 - val_mean_absolute_error: 0.0334
# Epoch 97/500
# 1620/1620 [==============================] - 0s 165us/step - loss: 3.0795e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 98/500
# 1620/1620 [==============================] - 0s 164us/step - loss: 3.0488e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 99/500
# 1620/1620 [==============================] - 0s 163us/step - loss: 3.1365e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 100/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 3.1783e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0010 - val_mean_absolute_error: 0.0270
# Epoch 101/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 3.3086e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0016 - val_mean_absolute_error: 0.0351
# Epoch 102/500
# 1620/1620 [==============================] - 0s 181us/step - loss: 3.0198e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0013 - val_mean_absolute_error: 0.0314
# Epoch 103/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 2.9711e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 104/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 3.0860e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0014 - val_mean_absolute_error: 0.0323
# Epoch 105/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 3.0475e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0012 - val_mean_absolute_error: 0.0292
# Epoch 106/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 3.3788e-04 - mean_absolute_error: 0.0140 - val_loss: 9.9873e-04 - val_mean_absolute_error: 0.0268
# Epoch 107/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 3.9561e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0017 - val_mean_absolute_error: 0.0359
# Epoch 108/500
# 1620/1620 [==============================] - 0s 164us/step - loss: 3.0491e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0015 - val_mean_absolute_error: 0.0335
# Epoch 109/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 3.2340e-04 - mean_absolute_error: 0.0136 - val_loss: 9.6125e-04 - val_mean_absolute_error: 0.0263
# Epoch 110/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 3.5839e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0017 - val_mean_absolute_error: 0.0368
# Epoch 111/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 3.8538e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0012 - val_mean_absolute_error: 0.0298
# Epoch 112/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 3.8527e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0016 - val_mean_absolute_error: 0.0349
# Epoch 113/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 3.0209e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0014 - val_mean_absolute_error: 0.0326
# Epoch 114/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 2.9129e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0011 - val_mean_absolute_error: 0.0288
# Epoch 115/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 2.8913e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0011 - val_mean_absolute_error: 0.0275
# Epoch 116/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 3.0349e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0016 - val_mean_absolute_error: 0.0347
# Epoch 117/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 2.9633e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 118/500
# 1620/1620 [==============================] - 0s 184us/step - loss: 3.2272e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 119/500
# 1620/1620 [==============================] - 0s 188us/step - loss: 3.5126e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0019 - val_mean_absolute_error: 0.0390
# Epoch 120/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 3.1338e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 121/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 3.1383e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 122/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 2.8215e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0018 - val_mean_absolute_error: 0.0369
# Epoch 123/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 3.0536e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297
# Epoch 124/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 3.0659e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0018 - val_mean_absolute_error: 0.0378
# Epoch 125/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 2.7923e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 126/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 2.7841e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0012 - val_mean_absolute_error: 0.0290
# Epoch 127/500
# 1620/1620 [==============================] - 0s 160us/step - loss: 2.6442e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 128/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 2.7578e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0013 - val_mean_absolute_error: 0.0308
# Epoch 129/500
# 1620/1620 [==============================] - 0s 183us/step - loss: 2.7197e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0014 - val_mean_absolute_error: 0.0326
# Epoch 130/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 2.5842e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0014 - val_mean_absolute_error: 0.0316
# Epoch 131/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 2.5597e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 132/500
# 1620/1620 [==============================] - 0s 163us/step - loss: 2.6945e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0015 - val_mean_absolute_error: 0.0341
# Epoch 133/500
# 1620/1620 [==============================] - 0s 183us/step - loss: 2.7624e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# Epoch 134/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 2.4806e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0017 - val_mean_absolute_error: 0.0355
# Epoch 135/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 2.6248e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0014 - val_mean_absolute_error: 0.0318
# Epoch 136/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 2.6726e-04 - mean_absolute_error: 0.0122 - val_loss: 9.5189e-04 - val_mean_absolute_error: 0.0263
# Epoch 137/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 2.7540e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0016 - val_mean_absolute_error: 0.0350
# Epoch 138/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 2.3784e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0014 - val_mean_absolute_error: 0.0326
# Epoch 139/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 2.6103e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0020 - val_mean_absolute_error: 0.0395
# Epoch 140/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 2.8294e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0016 - val_mean_absolute_error: 0.0347
# Epoch 141/500
# 1620/1620 [==============================] - 0s 182us/step - loss: 2.3585e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0015 - val_mean_absolute_error: 0.0327
# Epoch 142/500
# 1620/1620 [==============================] - 0s 164us/step - loss: 2.3766e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 143/500
# 1620/1620 [==============================] - 0s 182us/step - loss: 2.4874e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0016 - val_mean_absolute_error: 0.0348
# Epoch 144/500
# 1620/1620 [==============================] - 0s 183us/step - loss: 2.6810e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# Epoch 145/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 2.3422e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0018 - val_mean_absolute_error: 0.0368
# Epoch 146/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 2.3824e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0014 - val_mean_absolute_error: 0.0322
# Epoch 147/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 2.2153e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0015 - val_mean_absolute_error: 0.0330
# Epoch 148/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 2.2803e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0018 - val_mean_absolute_error: 0.0373
# Epoch 149/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 2.3588e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0015 - val_mean_absolute_error: 0.0328
# Epoch 150/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 2.2273e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0014 - val_mean_absolute_error: 0.0318
# Epoch 151/500
# 1620/1620 [==============================] - 0s 187us/step - loss: 2.4705e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0017 - val_mean_absolute_error: 0.0352
# Epoch 152/500
# 1620/1620 [==============================] - 0s 184us/step - loss: 2.2129e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0013 - val_mean_absolute_error: 0.0312
# Epoch 153/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 2.1407e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297
# Epoch 154/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 2.1377e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0014 - val_mean_absolute_error: 0.0321
# Epoch 155/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 2.3622e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0014 - val_mean_absolute_error: 0.0315
# Epoch 156/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 2.3262e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0014 - val_mean_absolute_error: 0.0321
# Epoch 157/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 2.2972e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0015 - val_mean_absolute_error: 0.0335
# Epoch 158/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 2.0562e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0016 - val_mean_absolute_error: 0.0346
# Epoch 159/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 2.1755e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0018 - val_mean_absolute_error: 0.0378
# Epoch 160/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 2.7053e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0019 - val_mean_absolute_error: 0.0384
# Epoch 161/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 2.4093e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0013 - val_mean_absolute_error: 0.0310
# Epoch 162/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 2.2524e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0014 - val_mean_absolute_error: 0.0322
# Epoch 163/500
# 1620/1620 [==============================] - 0s 159us/step - loss: 1.9978e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0016 - val_mean_absolute_error: 0.0343
# Epoch 164/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 2.0826e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0019 - val_mean_absolute_error: 0.0379
# Epoch 165/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 1.9356e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0014 - val_mean_absolute_error: 0.0322
# Epoch 166/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 2.0714e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0018 - val_mean_absolute_error: 0.0368
# Epoch 167/500
# 1620/1620 [==============================] - 0s 163us/step - loss: 1.9728e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0013 - val_mean_absolute_error: 0.0312
# Epoch 168/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 1.9644e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0019 - val_mean_absolute_error: 0.0379
# Epoch 169/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 2.2151e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0017 - val_mean_absolute_error: 0.0362
# Epoch 170/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 2.0445e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0014 - val_mean_absolute_error: 0.0322
# Epoch 171/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 2.2820e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0012 - val_mean_absolute_error: 0.0293
# Epoch 172/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 2.0372e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0015 - val_mean_absolute_error: 0.0333
# Epoch 173/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 2.4082e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0020 - val_mean_absolute_error: 0.0398
# Epoch 174/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 2.2080e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0018 - val_mean_absolute_error: 0.0379
# Epoch 175/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 1.9806e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0018 - val_mean_absolute_error: 0.0378
# Epoch 176/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 2.0681e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 177/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.9380e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0018 - val_mean_absolute_error: 0.0369
# Epoch 178/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 1.8657e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0015 - val_mean_absolute_error: 0.0338
# Epoch 179/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 1.8364e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0014 - val_mean_absolute_error: 0.0315
# Epoch 180/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 1.7760e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0015 - val_mean_absolute_error: 0.0337
# Epoch 181/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.8645e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0013 - val_mean_absolute_error: 0.0315
# Epoch 182/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 1.7942e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 183/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.7763e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0017 - val_mean_absolute_error: 0.0356
# Epoch 184/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.8360e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0013 - val_mean_absolute_error: 0.0310
# Epoch 185/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 2.0987e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0017 - val_mean_absolute_error: 0.0369
# Epoch 186/500
# 1620/1620 [==============================] - 0s 181us/step - loss: 1.8950e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 187/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.7495e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0016 - val_mean_absolute_error: 0.0355
# Epoch 188/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.7151e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0010 - val_mean_absolute_error: 0.0276
# Epoch 189/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 1.8153e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0015 - val_mean_absolute_error: 0.0339
# Epoch 190/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.7938e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0015 - val_mean_absolute_error: 0.0335
# Epoch 191/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.6752e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# Epoch 192/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 1.6960e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0014 - val_mean_absolute_error: 0.0326
# Epoch 193/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.6066e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 194/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.8203e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0017 - val_mean_absolute_error: 0.0368
# Epoch 195/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.6975e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0016 - val_mean_absolute_error: 0.0349
# Epoch 196/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 1.8778e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 197/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.7173e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0011 - val_mean_absolute_error: 0.0275
# Epoch 198/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.6286e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 199/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 1.7122e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0017 - val_mean_absolute_error: 0.0371
# Epoch 200/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 1.9616e-04 - mean_absolute_error: 0.0106 - val_loss: 9.2334e-04 - val_mean_absolute_error: 0.0258
# Epoch 201/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 1.8057e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0013 - val_mean_absolute_error: 0.0316
# Epoch 202/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 2.2334e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 203/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 2.5089e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0016 - val_mean_absolute_error: 0.0348
# Epoch 204/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 1.8395e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0010 - val_mean_absolute_error: 0.0271
# Epoch 205/500
# 1620/1620 [==============================] - 0s 166us/step - loss: 1.8563e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 206/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 1.5337e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0016 - val_mean_absolute_error: 0.0350
# Epoch 207/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 1.5456e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0012 - val_mean_absolute_error: 0.0295
# Epoch 208/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 1.5052e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0011 - val_mean_absolute_error: 0.0283
# Epoch 209/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 1.5899e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0015 - val_mean_absolute_error: 0.0343
# Epoch 210/500
# 1620/1620 [==============================] - 0s 191us/step - loss: 1.5808e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0010 - val_mean_absolute_error: 0.0272
# Epoch 211/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 1.6407e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 212/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 1.4879e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0012 - val_mean_absolute_error: 0.0295
# Epoch 213/500
# 1620/1620 [==============================] - 0s 166us/step - loss: 1.7581e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0013 - val_mean_absolute_error: 0.0309
# Epoch 214/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.5073e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297
# Epoch 215/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.4469e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0015 - val_mean_absolute_error: 0.0342
# Epoch 216/500
# 1620/1620 [==============================] - 0s 163us/step - loss: 1.6458e-04 - mean_absolute_error: 0.0096 - val_loss: 9.8534e-04 - val_mean_absolute_error: 0.0266
# Epoch 217/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 1.8146e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0017 - val_mean_absolute_error: 0.0362
# Epoch 218/500
# 1620/1620 [==============================] - 0s 166us/step - loss: 1.6584e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0011 - val_mean_absolute_error: 0.0282
# Epoch 219/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 1.4378e-04 - mean_absolute_error: 0.0088 - val_loss: 9.1119e-04 - val_mean_absolute_error: 0.0256
# Epoch 220/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 1.8472e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0014 - val_mean_absolute_error: 0.0330
# Epoch 221/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 1.7478e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0015 - val_mean_absolute_error: 0.0339
# Epoch 222/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 1.9241e-04 - mean_absolute_error: 0.0105 - val_loss: 8.2560e-04 - val_mean_absolute_error: 0.0244
# Epoch 223/500
# 1620/1620 [==============================] - 0s 186us/step - loss: 2.2055e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0018 - val_mean_absolute_error: 0.0378
# Epoch 224/500
# 1620/1620 [==============================] - 0s 188us/step - loss: 2.1976e-04 - mean_absolute_error: 0.0117 - val_loss: 8.0367e-04 - val_mean_absolute_error: 0.0242
# Epoch 225/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 1.8558e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0010 - val_mean_absolute_error: 0.0271
# Epoch 226/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.4572e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0013 - val_mean_absolute_error: 0.0318
# Epoch 227/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 1.4003e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0012 - val_mean_absolute_error: 0.0304
# Epoch 228/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 1.4321e-04 - mean_absolute_error: 0.0088 - val_loss: 8.8349e-04 - val_mean_absolute_error: 0.0253
# Epoch 229/500
# 1620/1620 [==============================] - 0s 165us/step - loss: 1.5039e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 230/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 1.5460e-04 - mean_absolute_error: 0.0093 - val_loss: 9.4888e-04 - val_mean_absolute_error: 0.0262
# Epoch 231/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 1.5010e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0016 - val_mean_absolute_error: 0.0356
# Epoch 232/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 1.3572e-04 - mean_absolute_error: 0.0085 - val_loss: 9.2972e-04 - val_mean_absolute_error: 0.0260
# Epoch 233/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.3178e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0012 - val_mean_absolute_error: 0.0299
# Epoch 234/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 1.3437e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 235/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 1.7095e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0011 - val_mean_absolute_error: 0.0283
# Epoch 236/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 1.3523e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0013 - val_mean_absolute_error: 0.0315
# Epoch 237/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 1.4679e-04 - mean_absolute_error: 0.0090 - val_loss: 9.8116e-04 - val_mean_absolute_error: 0.0267
# Epoch 238/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 1.8094e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0011 - val_mean_absolute_error: 0.0284
# Epoch 239/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 1.4512e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0013 - val_mean_absolute_error: 0.0317
# Epoch 240/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.3699e-04 - mean_absolute_error: 0.0086 - val_loss: 9.6265e-04 - val_mean_absolute_error: 0.0265
# Epoch 241/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.3721e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0012 - val_mean_absolute_error: 0.0303
# Epoch 242/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 1.4315e-04 - mean_absolute_error: 0.0089 - val_loss: 8.5079e-04 - val_mean_absolute_error: 0.0248
# Epoch 243/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.8761e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0016 - val_mean_absolute_error: 0.0353
# Epoch 244/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 1.4773e-04 - mean_absolute_error: 0.0091 - val_loss: 9.2221e-04 - val_mean_absolute_error: 0.0260
# Epoch 245/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 1.3216e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0010 - val_mean_absolute_error: 0.0275
# Epoch 246/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 1.2821e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0011 - val_mean_absolute_error: 0.0291
# Epoch 247/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 1.3428e-04 - mean_absolute_error: 0.0086 - val_loss: 7.5967e-04 - val_mean_absolute_error: 0.0234
# Epoch 248/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.5154e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# Epoch 249/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 1.4058e-04 - mean_absolute_error: 0.0087 - val_loss: 9.1943e-04 - val_mean_absolute_error: 0.0259
# Epoch 250/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.1978e-04 - mean_absolute_error: 0.0080 - val_loss: 8.3813e-04 - val_mean_absolute_error: 0.0247
# Epoch 251/500
# 1620/1620 [==============================] - 0s 204us/step - loss: 1.1755e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0012 - val_mean_absolute_error: 0.0302
# Epoch 252/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 1.3997e-04 - mean_absolute_error: 0.0088 - val_loss: 7.9028e-04 - val_mean_absolute_error: 0.0239
# Epoch 253/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.2243e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0010 - val_mean_absolute_error: 0.0274
# Epoch 254/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 1.3240e-04 - mean_absolute_error: 0.0085 - val_loss: 9.1502e-04 - val_mean_absolute_error: 0.0258
# Epoch 255/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.3767e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0014 - val_mean_absolute_error: 0.0330
# Epoch 256/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 1.2267e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0011 - val_mean_absolute_error: 0.0286
# Epoch 257/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 1.3866e-04 - mean_absolute_error: 0.0085 - val_loss: 9.2900e-04 - val_mean_absolute_error: 0.0260
# Epoch 258/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.2629e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0012 - val_mean_absolute_error: 0.0305
# Epoch 259/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.3226e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0011 - val_mean_absolute_error: 0.0286
# Epoch 260/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 1.1563e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0010 - val_mean_absolute_error: 0.0277
# Epoch 261/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 1.5075e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0014 - val_mean_absolute_error: 0.0328
# Epoch 262/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 1.5679e-04 - mean_absolute_error: 0.0096 - val_loss: 9.2719e-04 - val_mean_absolute_error: 0.0259
# Epoch 263/500
# 1620/1620 [==============================] - 0s 163us/step - loss: 1.2146e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0010 - val_mean_absolute_error: 0.0273
# Epoch 264/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 1.2256e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 265/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 1.1923e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0010 - val_mean_absolute_error: 0.0271
# Epoch 266/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.2080e-04 - mean_absolute_error: 0.0081 - val_loss: 8.9225e-04 - val_mean_absolute_error: 0.0254
# Epoch 267/500
# 1620/1620 [==============================] - 0s 159us/step - loss: 1.2883e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0014 - val_mean_absolute_error: 0.0321
# Epoch 268/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 1.1286e-04 - mean_absolute_error: 0.0078 - val_loss: 7.8719e-04 - val_mean_absolute_error: 0.0238
# Epoch 269/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 1.3576e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0014 - val_mean_absolute_error: 0.0324
# Epoch 270/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 2.1088e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0011 - val_mean_absolute_error: 0.0286
# Epoch 271/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 1.4266e-04 - mean_absolute_error: 0.0089 - val_loss: 8.5362e-04 - val_mean_absolute_error: 0.0249
# Epoch 272/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 1.4357e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0012 - val_mean_absolute_error: 0.0304
# Epoch 273/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 1.4879e-04 - mean_absolute_error: 0.0092 - val_loss: 9.4345e-04 - val_mean_absolute_error: 0.0262
# Epoch 274/500
# ...
# Epoch 410/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 9.3472e-05 - mean_absolute_error: 0.0071 - val_loss: 0.0013 - val_mean_absolute_error: 0.0309
# Epoch 411/500
# 1620/1620 [==============================] - 0s 182us/step - loss: 7.9977e-05 - mean_absolute_error: 0.0064 - val_loss: 9.0281e-04 - val_mean_absolute_error: 0.0256
# Epoch 412/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 7.8772e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0012 - val_mean_absolute_error: 0.0302
# Epoch 413/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 7.9424e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0013 - val_mean_absolute_error: 0.0317
# Epoch 414/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 8.1448e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0014 - val_mean_absolute_error: 0.0321
# Epoch 415/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 9.3239e-05 - mean_absolute_error: 0.0073 - val_loss: 0.0012 - val_mean_absolute_error: 0.0294
# Epoch 416/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 9.1589e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0010 - val_mean_absolute_error: 0.0271
# Epoch 417/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 8.3475e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0013 - val_mean_absolute_error: 0.0320
# Epoch 418/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 1.1244e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297
# Epoch 419/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 1.2147e-04 - mean_absolute_error: 0.0084 - val_loss: 9.7841e-04 - val_mean_absolute_error: 0.0266
# Epoch 420/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.0157e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0010 - val_mean_absolute_error: 0.0276
# Epoch 421/500
# 1620/1620 [==============================] - 0s 165us/step - loss: 8.4371e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0013 - val_mean_absolute_error: 0.0313
# Epoch 422/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 8.8869e-05 - mean_absolute_error: 0.0068 - val_loss: 9.0760e-04 - val_mean_absolute_error: 0.0257
# Epoch 423/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 8.0259e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0012 - val_mean_absolute_error: 0.0290
# Epoch 424/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 9.4099e-05 - mean_absolute_error: 0.0072 - val_loss: 0.0013 - val_mean_absolute_error: 0.0310
# Epoch 425/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 8.4335e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0011 - val_mean_absolute_error: 0.0284
# Epoch 426/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 8.4679e-05 - mean_absolute_error: 0.0068 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 427/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 8.8831e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0011 - val_mean_absolute_error: 0.0283
# Epoch 428/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 9.6826e-05 - mean_absolute_error: 0.0074 - val_loss: 9.5242e-04 - val_mean_absolute_error: 0.0262
# Epoch 429/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 9.9972e-05 - mean_absolute_error: 0.0075 - val_loss: 0.0014 - val_mean_absolute_error: 0.0327
# Epoch 430/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 1.0826e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0011 - val_mean_absolute_error: 0.0289
# Epoch 431/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 8.4444e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0016 - val_mean_absolute_error: 0.0349
# Epoch 432/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 8.3629e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 433/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 7.9031e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 434/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 8.1463e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 435/500
# 1620/1620 [==============================] - 0s 166us/step - loss: 8.5774e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0013 - val_mean_absolute_error: 0.0308
# Epoch 436/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 8.2503e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0012 - val_mean_absolute_error: 0.0304
# Epoch 437/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 8.4825e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0011 - val_mean_absolute_error: 0.0287
# Epoch 438/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 8.6554e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0014 - val_mean_absolute_error: 0.0319
# Epoch 439/500
# 1620/1620 [==============================] - 0s 186us/step - loss: 9.5544e-05 - mean_absolute_error: 0.0072 - val_loss: 0.0013 - val_mean_absolute_error: 0.0317
# Epoch 440/500
# 1620/1620 [==============================] - 0s 164us/step - loss: 1.1392e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0014 - val_mean_absolute_error: 0.0323
# Epoch 441/500
# 1620/1620 [==============================] - 0s 181us/step - loss: 1.2505e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0010 - val_mean_absolute_error: 0.0269
# Epoch 442/500
# 1620/1620 [==============================] - 0s 182us/step - loss: 1.3104e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0014 - val_mean_absolute_error: 0.0318
# Epoch 443/500
# 1620/1620 [==============================] - 0s 184us/step - loss: 1.0637e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 444/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 1.1102e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0010 - val_mean_absolute_error: 0.0275
# Epoch 445/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 8.7004e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 446/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 9.1509e-05 - mean_absolute_error: 0.0071 - val_loss: 0.0011 - val_mean_absolute_error: 0.0290
# Epoch 447/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 8.7143e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0014 - val_mean_absolute_error: 0.0316
# Epoch 448/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 7.9469e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0014 - val_mean_absolute_error: 0.0326
# Epoch 449/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 7.5257e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0013 - val_mean_absolute_error: 0.0312
# Epoch 450/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 9.5322e-05 - mean_absolute_error: 0.0073 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 451/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 7.9080e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0015 - val_mean_absolute_error: 0.0345
# Epoch 452/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 7.8243e-05 - mean_absolute_error: 0.0064 - val_loss: 9.6102e-04 - val_mean_absolute_error: 0.0264
# Epoch 453/500
# 1620/1620 [==============================] - 0s 162us/step - loss: 8.1555e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0014 - val_mean_absolute_error: 0.0327
# Epoch 454/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 9.1391e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0011 - val_mean_absolute_error: 0.0288
# Epoch 455/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 8.0771e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0014 - val_mean_absolute_error: 0.0319
# Epoch 456/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 8.1743e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0014 - val_mean_absolute_error: 0.0331
# Epoch 457/500
# 1620/1620 [==============================] - 0s 162us/step - loss: 8.0435e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 458/500
# 1620/1620 [==============================] - 0s 160us/step - loss: 8.8127e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0013 - val_mean_absolute_error: 0.0318
# Epoch 459/500
# 1620/1620 [==============================] - 0s 181us/step - loss: 8.0801e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0013 - val_mean_absolute_error: 0.0312
# Epoch 460/500
# 1620/1620 [==============================] - 0s 170us/step - loss: 7.7036e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0013 - val_mean_absolute_error: 0.0312
# Epoch 461/500
# 1620/1620 [==============================] - 0s 177us/step - loss: 7.5622e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 462/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 7.8017e-05 - mean_absolute_error: 0.0064 - val_loss: 9.0170e-04 - val_mean_absolute_error: 0.0256
# Epoch 463/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 7.9068e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0013 - val_mean_absolute_error: 0.0310
# Epoch 464/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 8.2208e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0018 - val_mean_absolute_error: 0.0379
# Epoch 465/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 8.7511e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297
# Epoch 466/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 7.8873e-05 - mean_absolute_error: 0.0064 - val_loss: 9.5391e-04 - val_mean_absolute_error: 0.0262
# Epoch 467/500
# 1620/1620 [==============================] - 0s 157us/step - loss: 8.8453e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0013 - val_mean_absolute_error: 0.0312
# Epoch 468/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 7.6620e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0013 - val_mean_absolute_error: 0.0309
# Epoch 469/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 8.3696e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0013 - val_mean_absolute_error: 0.0309
# Epoch 470/500
# 1620/1620 [==============================] - 0s 172us/step - loss: 8.2625e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0014 - val_mean_absolute_error: 0.0318
# Epoch 471/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 8.7919e-05 - mean_absolute_error: 0.0068 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 472/500
# 1620/1620 [==============================] - 0s 181us/step - loss: 8.7452e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0017 - val_mean_absolute_error: 0.0368
# Epoch 473/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 1.0566e-04 - mean_absolute_error: 0.0078 - val_loss: 9.3077e-04 - val_mean_absolute_error: 0.0260
# Epoch 474/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 9.6018e-05 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0289
# Epoch 475/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 9.4664e-05 - mean_absolute_error: 0.0073 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 476/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 8.2696e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0012 - val_mean_absolute_error: 0.0302
# Epoch 477/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 8.4645e-05 - mean_absolute_error: 0.0068 - val_loss: 0.0015 - val_mean_absolute_error: 0.0336
# Epoch 478/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 8.0007e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0014 - val_mean_absolute_error: 0.0317
# Epoch 479/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 9.3609e-05 - mean_absolute_error: 0.0072 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 480/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 1.1114e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0021 - val_mean_absolute_error: 0.0406
# Epoch 481/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 9.8241e-05 - mean_absolute_error: 0.0074 - val_loss: 9.5237e-04 - val_mean_absolute_error: 0.0262
# Epoch 482/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 8.8000e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0012 - val_mean_absolute_error: 0.0301
# Epoch 483/500
# 1620/1620 [==============================] - 0s 167us/step - loss: 8.7421e-05 - mean_absolute_error: 0.0069 - val_loss: 9.4322e-04 - val_mean_absolute_error: 0.0263
# Epoch 484/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 9.4267e-05 - mean_absolute_error: 0.0073 - val_loss: 0.0016 - val_mean_absolute_error: 0.0350
# Epoch 485/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 8.3214e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0011 - val_mean_absolute_error: 0.0277
# Epoch 486/500
# 1620/1620 [==============================] - 0s 171us/step - loss: 8.9310e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0015 - val_mean_absolute_error: 0.0337
# Epoch 487/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 8.2707e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0015 - val_mean_absolute_error: 0.0331
# Epoch 488/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 9.1865e-05 - mean_absolute_error: 0.0072 - val_loss: 0.0020 - val_mean_absolute_error: 0.0399
# Epoch 489/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 9.1893e-05 - mean_absolute_error: 0.0072 - val_loss: 0.0012 - val_mean_absolute_error: 0.0293
# Epoch 490/500
# 1620/1620 [==============================] - 0s 169us/step - loss: 8.4597e-05 - mean_absolute_error: 0.0068 - val_loss: 8.9594e-04 - val_mean_absolute_error: 0.0258
# Epoch 491/500
# 1620/1620 [==============================] - 0s 176us/step - loss: 8.7218e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0014 - val_mean_absolute_error: 0.0328
# Epoch 492/500
# 1620/1620 [==============================] - 0s 178us/step - loss: 8.0432e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0013 - val_mean_absolute_error: 0.0308
# Epoch 493/500
# 1620/1620 [==============================] - 0s 179us/step - loss: 9.0922e-05 - mean_absolute_error: 0.0071 - val_loss: 0.0013 - val_mean_absolute_error: 0.0313
# Epoch 494/500
# 1620/1620 [==============================] - 0s 185us/step - loss: 7.6731e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0013 - val_mean_absolute_error: 0.0312
# Epoch 495/500
# 1620/1620 [==============================] - 0s 168us/step - loss: 7.7784e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0016 - val_mean_absolute_error: 0.0349
# Epoch 496/500
# 1620/1620 [==============================] - 0s 180us/step - loss: 9.2347e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0012 - val_mean_absolute_error: 0.0292
# Epoch 497/500
# 1620/1620 [==============================] - 0s 183us/step - loss: 7.5500e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0012 - val_mean_absolute_error: 0.0301
# Epoch 498/500
# 1620/1620 [==============================] - 0s 173us/step - loss: 8.2504e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0010 - val_mean_absolute_error: 0.0269
# Epoch 499/500
# 1620/1620 [==============================] - 0s 174us/step - loss: 7.7941e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0014 - val_mean_absolute_error: 0.0328
# Epoch 500/500
# 1620/1620 [==============================] - 0s 175us/step - loss: 8.3179e-05 - mean_absolute_error: 0.0067 - val_loss: 8.8225e-04 - val_mean_absolute_error: 0.0253

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model = load_model('stockFri Jun 14 07:37:30 2019.h5')  # best model 불러오기
test_predict = model.predict(Xtest)
test_predict_back = scalery.inverse_transform(test_predict)
ytest_back = scalery.inverse_transform(ytest)

# %%
# Plot predictions
plt.plot(ytest_back, label = 'Y')
plt.plot(test_predict_back, label = 'Y_predicted')
plt.xlabel("Time Period")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %%
mean_absolute_error(test_predict_back, ytest_back), np.mean(test_predict_back / ytest_back) - 1
# Out:
# (1.3186643747183, 0.005226116747621301)

# %%
# !jupyter nbconvert --to html --TemplateExporter.exclude_input=True WTI_oil_price_predict.ipynb
# Out:
# [NbConvertApp] Converting notebook WTI_oil_price_predict.ipynb to html
# [NbConvertApp] Writing 549358 bytes to WTI_oil_price_predict.html
